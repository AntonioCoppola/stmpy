# %% [markdown]
# ## Environment Setup

# %%
# Set up the environment
# %load_ext rpy2.ipython
import rpy2.robjects as robjects
import numpy as np
import scipy as sp
import time
from scipy import optimize
import os
import pandas as pd
from scipy import io
from rpy2.robjects import pandas2ri
import rpy2

# %% [markdown]
# ## R Imports for STM

# %%
for f in os.listdir("R"):
    if f not in ['.DS_Store', '.Rapp.history', 'box', 'e_step_spark.R']:
        robjects.r.source("R/" + f)

# %%
robjects.r('''
    library(Matrix); library(stringr); library(splines); library(matrixStats);
    library(slam); library(lda); library(glmnet); library(magrittr)
''')
# Out:
# array(['magrittr', 'glmnet', 'foreach', 'lda', 'slam', 'matrixStats',
#        'splines', 'stringr', 'Matrix', 'tools', 'stats', 'graphics',
#        'grDevices', 'utils', 'datasets', 'methods', 'base'],
#       dtype='|S11')

# %% [markdown]
# ## Sample run with R code

# %%
# Subsample the corpus to only consider articles mentioning 'monte carlo'
cond_mat_mc = pd.read_csv('cond_mat_mc.csv')[:15]
# %Rpush cond_mat_mc

# %%
# Prep the corpus
robjects.r('''
    processed_corpus_temp = textProcessor(cond_mat_mc$abstract, metadata=cond_mat_mc, lowercase=TRUE)
    processed_corpus = prepDocuments(processed_corpus_temp$documents,
                                 processed_corpus_temp$vocab, 
                                 processed_corpus_temp$meta,
                                 lower.thresh=1)
    processed_corpus$meta$date %<>% as.Date
    rm(processed_corpus_temp); invisible(gc())
''');
# Out:
# Building corpus...
# Converting to Lower Case...
# Removing stopwords...
# Removing numbers...
# Removing punctuation...
# Stemming...
# Creating Output...
# Removing 400 of 539 terms (400 of 836 tokens) due to frequency
# Your corpus now has 15 documents, 139 terms and 436 tokens.

# %%
robjects.r('''
    fit = stm(processed_corpus$documents, 
             processed_corpus$vocab,
             K=20, prevalence=~s(date),
             data=processed_corpus$meta,
             init.type = 'Spectral',
             seed=02138)
''');

# %%
robjects.r('''

    # Extract objects
    documents <- fit$documents
    vocab <- fit$vocab
    settings <- fit$settings 
    model <- fit$model
    verbose <- settings$verbose
    
    # Initialize parameters
    ngroups <- settings$ngroups
    if(is.null(model)) {
    
        if(verbose) cat("Beginning Initialization.\n")
        model <- stm.init(documents, settings)
        
        # If using the Lee and Mimno method of setting K, update the settings
        if(settings$dim$K==0) settings$dim$K <- nrow(model$beta[[1]])
        
        # Unpack
        mu <- list(mu=model$mu)
        sigma <- model$sigma
        beta <- list(beta=model$beta)
        if(!is.null(model$kappa)) beta$kappa <- model$kappa
        lambda <- model$lambda
        convergence <- NULL 
        
        # Discard the old object
        # rm(model)
    } else {
    
        if(verbose) cat("Restarting Model...\n")
        
        # Extract from a standard STM object so we can simply continue
        mu <- model$mu
        beta <- list(beta=lapply(model$beta$logbeta, exp))
        if(!is.null(model$beta$kappa)) beta$kappa <- model$beta$kappa
        sigma <- model$sigma
        lambda <- model$eta
        convergence <- model$convergence
        
        # Manually declare the model not converged or it will stop after the first iteration
        convergence$stopits <- FALSE
        convergence$converged <- FALSE
        
        # Iterate by 1 as that would have happened otherwise
        convergence$its <- convergence$its + 1 
    }    
  
    #Pull out some book keeping elements
    ntokens <- sum(settings$dim$wcounts$x)
    betaindex <- settings$covariates$betaindex
    stopits <- FALSE
    if(ngroups!=1) {
        groups <- cut(1:length(documents), breaks=ngroups, labels=FALSE) 
    }
    suffstats <- vector(mode="list", length=ngroups)
''');
# Out:
# Beginning Initialization.
# 	 Calculating the gram matrix...
# 	 Finding anchor words...
#  	....................
# 	 Recovering initialization...
#  	.
# Initialization complete.

# %%
# Conversion functions
def rlist_2py(rlist):
    return dict(zip(rlist.names,
               list(rlist)))

def pybeta_ss_2r(beta):
    return robjects.ListVector( 
        robjects.ListVector({str(i+1):robjects.Matrix(mat) for i, mat in enumerate(beta)}))

def pybeta_2r(beta):
    return robjects.ListVector({'beta':
                     robjects.ListVector({str(i+1):robjects.Matrix(mat) for i, mat in enumerate(beta)})
                    })

def rmu_2py(mu):
    out = {'mu': np.array(mu[0])}
    if len(mu) > 1:
        out['gamma'] = np.array(mu[1])
    else:
        out['gamma'] = None
    return out

# %%
# Get the settings
fit = dict(zip( robjects.globalenv['fit'].names, 
         list( robjects.globalenv['fit'])))
settings = dict(zip( fit['settings'].names, 
         list(fit['settings'])))
K, A, V, N = [int(settings['dim'][i][0]) for i in range(4)]

# %%
# Some setup for EM, retrieving the R objects
stopits = False
ngroups = int(robjects.globalenv['ngroups'][0])
documents = [np.array(x) for x in list(robjects.globalenv['documents'])]
beta_index = np.array(robjects.globalenv['betaindex'])
beta = [np.array(x) for x in robjects.globalenv['beta'][0]]
update_mu = True
Lambda = np.array(robjects.globalenv['lambda'])
#mu = np.array(robjects.globalenv['mu'][0])
mu = rmu_2py(robjects.globalenv['mu'])
sigma = np.array(robjects.globalenv['sigma'])
verbose = settings['verbose'][0]

# %%
# Likelihood
def likelihood(eta, beta, doc_ct, mu, siginv):
    exp_eta = np.exp(np.append(eta, np.array([0])))
    ndoc = np.sum(doc_ct)
    part1 = np.dot(np.log(np.dot(exp_eta, beta)), doc_ct) - ndoc * np.log(np.sum(exp_eta))
    diff = mu.T - eta
    part2 = 0.5 * float(np.dot(np.dot(diff, siginv), diff.T))
    return part2 - part1

# %%
# Gradient
def grad(eta, beta, doc_ct, mu, siginv):
    exp_eta = np.exp(np.append(eta, [0]))
    beta_prime = np.apply_along_axis(lambda x: x * exp_eta, 0, beta)
    part1 = np.dot(beta_prime, doc_ct/np.sum(beta_prime, 0).T) - (np.sum(doc_ct)/ np.sum(exp_eta)) * exp_eta
    diff = mu.T - eta
    part2 = np.dot(siginv, diff.T)
    part1 = part1[:len(part1)-1]
    return (part2.T - part1).flatten()

# %%
# Hessian - Phi - Bound
def hpb(eta, beta, doc_ct, mu, siginv, sigmaentropy):
    
    # Compute the Hessian
    exp_eta = np.exp(np.append(eta, [0]))
    theta = np.reshape(exp_eta/np.sum(exp_eta), (len(exp_eta), -1)).T
    EB = np.apply_along_axis(lambda x: x * exp_eta, 0, beta)
    EB = np.apply_along_axis(lambda x: x * (np.sqrt(doc_ct).T) / np.sum(EB,0), 1, EB)
    hess = np.dot(EB, EB.T) - np.sum(doc_ct) * np.dot(theta.T, theta)    
    EB = np.apply_along_axis(lambda x: x * np.sqrt(doc_ct).T, 1, EB)
    hess[np.diag_indices_from(hess)] = hess[np.diag_indices_from(hess)] - np.sum(EB, 1) + np.sum(doc_ct) * theta
    hess = hess[:hess.shape[0]-1,:hess.shape[1]-1] + siginv

    # Invert via Cholesky decomposition
    try:
        nu = np.linalg.cholesky(hess)
    except:
        dvec = np.array(np.diag(hess))
        magnitudes = np.sum(np.abs(hess), 1) - abs(dvec)
        Km1 = len(dvec)
        for i in range(Km1):
            if dvec[i] < magnitudes[i]:
                dvec[i] = magnitudes[i]
        hess[np.diag_indices_from(hess)] = dvec
        nu = np.linalg.cholesky(hess)

    # Finish construction
    det_term = -np.sum(np.log(np.diag(nu)))
    nu = np.linalg.inv(np.triu(nu))
    nu = np.dot(nu, nu.T)
    diff = eta - mu.flatten()

    # Compute the bound
    bound = (np.dot(np.log(np.dot(theta, beta)), doc_ct) + det_term 
             - 0.5 * np.dot(diff.T, np.dot(siginv, diff)) - sigmaentropy)

    # Construct output
    out = {'phis': EB,
           'eta': {'lambda': eta, 'nu': nu},
           'bound': bound}
    return out

# %%
# Code for worker node dispatch
def estep_docloop(doc_item, siginv, sigmaentropy):
    
    # Extract the info
    doc_ct = doc_item['doc'][1]
    eta = doc_item['init']
    beta = doc_item['beta_i']
    mu = doc_item['mu_i']
    
    # Run the step
    try:
        optim_par = sp.optimize.minimize(likelihood, eta, args=(beta, doc_ct, mu, siginv), 
                                method='BFGS')
        out = hpb(optim_par.x, beta, doc_ct, mu, siginv, sigmaentropy)
    except:
        import scipy as sp
        import numpy as np
        from scipy import optimize
        optim_par = sp.optimize.minimize(likelihood, eta, args=(beta, doc_ct, mu, siginv), 
                                method='BFGS')
        out = hpb(optim_par.x, beta, doc_ct, mu, siginv, sigmaentropy)
    
    # Also include aspect and  in the output
    out['aspect'] = doc_item['aspect']
    out['words'] = doc_item['doc'][0]
    
    return out

# %%
# Estep on Spark
def estep_spark(documents, beta_index, beta, Lambda_old,
                mu, sigma, verbose, sc, update_mu=False):
    
    # Initialize sufficient statistics
    sigma_ss = np.zeros((K-1, K-1))
    beta_ss = [np.zeros((K, V)) for i in range(A)]
    Lambda = np.zeros((N, N))
    siginv = np.linalg.inv(sigma)
    sigmaentropy = np.log(np.abs(np.linalg.det(sigma))) * 0.5
    
    # Parallelize document collection
    collection = [{'doc':doc, 'aspect': int(aspect), 'init': init} 
                  for (doc, aspect, init) in zip(documents, beta_index, Lambda_old)]
    for i, item in enumerate(collection):
        item['beta_i'] = beta[item['aspect']-1][:,[x-1 for x in item['doc'][0]]]
        if mu['gamma'] is None:
            item['mu_i'] = mu['mu']
        else:
            item['mu_i'] = mu['mu'][:,i]
    
    # Run estep on Spark
    collection_par = sc.parallelize(collection)
    doc_results = collection_par.map(lambda x: estep_docloop(x, siginv, sigmaentropy)).collect()
    
    # Update sufficient statistics
    sigma_ss += reduce(lambda a, b: a + b, [doc['eta']['nu'] for doc in doc_results])
    bound = np.array([doc['bound'][0] for doc in doc_results])
    Lambda = np.array([doc['eta']['lambda'] for doc in doc_results])
    
    # Update beta
    for doc in doc_results:
        beta_ss[doc['aspect']-1][:,[j-1 for j in doc['words']]] -= doc['phis']
    
    return sigma_ss, beta_ss, bound, Lambda

# %%
# Clear the convergence object
try:
    del convergence
except:
    pass

# Initiate counter
i = 0

# Run EM!
while stopits is not True:
    
    # Non-blocked updates
    if ngroups==1:
        
        # Run the E-step
        sigma_ss, beta_ss, bound_ss, Lambda = estep_spark(documents, beta_index, beta, 
                                                          Lambda, mu, sigma, verbose, sc, False)
        if verbose:
            print "Completed E-Step, Iteration " +  str(i+1)
        
        # Run the M-step
        mu = rmu_2py(robjects.globalenv['opt.mu'](Lambda, 
                             robjects.r("settings$gamma$mode"),
                             robjects.r("settings$covariates$X"),
                             robjects.r("settings$gamma$enet")))
        sigma = np.array(robjects.r("opt.sigma")(sigma_ss, 
                                                 Lambda, 
                                                 mu['mu'], 
                                                 float(robjects.r("settings$sigma$prior"))))
        beta_new_temp = robjects.globalenv['opt.beta'](pybeta_ss_2r(beta_ss), 
                                                       robjects.r('beta$kappa'), 
                                                       robjects.r('settings'))
        beta_new = [np.array(x) for x in beta_new_temp[0]]
        
        if verbose:
            print "Completed M-Step, Iteration " +  str(i+1)
      
    # Blocked updates are not yet supported
    else:
        raise Exception("Blocked inference not yet supported. ")
    
    # Check for convergence
    try:
        convergence = robjects.globalenv['convergence.check'](bound_ss, convergence, 
                                                              robjects.globalenv['settings'])
    except:
        convergence = robjects.globalenv['convergence.check'](bound_ss, 
                                                              robjects.globalenv['convergence'], 
                                                              robjects.globalenv['settings'])
        
    # Print updates if we have not converged
    stopits = bool(rlist_2py(convergence)['stopits'][0])
    if stopits is not True and verbose:
        robjects.r.report(convergence, robjects.r.ntokens, pybeta_2r(beta),
                 robjects.r.vocab, robjects.r('settings$topicreportevery'),
                 verbose);
    
    # Increase counter
    i += 1
    print ""
# Out:
# Completed E-Step, Iteration 1
# Completed M-Step, Iteration 1
# Completing Iteration 1 (approx. per word bound = -3.684)
#
# Completed E-Step, Iteration 2
# Completed M-Step, Iteration 2
# Completing Iteration 2 (approx. per word bound = -3.637, relative change = 1.271e-02)
#
# Completed E-Step, Iteration 3
# Completed M-Step, Iteration 3
# Completing Iteration 3 (approx. per word bound = -3.623, relative change = 3.853e-03)
#
# Completed E-Step, Iteration 4
# Completed M-Step, Iteration 4
# Completing Iteration 4 (approx. per word bound = -3.615, relative change = 2.148e-03)
#
# Completed E-Step, Iteration 5
# Completed M-Step, Iteration 5
# Completing Iteration 5 (approx. per word bound = -3.610, relative change = 1.422e-03)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 6
# Completed M-Step, Iteration 6
# Completing Iteration 6 (approx. per word bound = -3.606, relative change = 1.019e-03)
#
# Completed E-Step, Iteration 7
# Completed M-Step, Iteration 7
# Completing Iteration 7 (approx. per word bound = -3.604, relative change = 7.695e-04)
#
# Completed E-Step, Iteration 8
# Completed M-Step, Iteration 8
# Completing Iteration 8 (approx. per word bound = -3.601, relative change = 6.037e-04)
#
# Completed E-Step, Iteration 9
# Completed M-Step, Iteration 9
# Completing Iteration 9 (approx. per word bound = -3.600, relative change = 4.885e-04)
#
# Completed E-Step, Iteration 10
# Completed M-Step, Iteration 10
# Completing Iteration 10 (approx. per word bound = -3.598, relative change = 4.057e-04)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 11
# Completed M-Step, Iteration 11
# Completing Iteration 11 (approx. per word bound = -3.597, relative change = 3.446e-04)
#
# Completed E-Step, Iteration 12
# Completed M-Step, Iteration 12
# Completing Iteration 12 (approx. per word bound = -3.596, relative change = 2.983e-04)
#
# Completed E-Step, Iteration 13
# Completed M-Step, Iteration 13
# Completing Iteration 13 (approx. per word bound = -3.595, relative change = 2.625e-04)
#
# Completed E-Step, Iteration 14
# Completed M-Step, Iteration 14
# Completing Iteration 14 (approx. per word bound = -3.594, relative change = 2.341e-04)
#
# Completed E-Step, Iteration 15
# Completed M-Step, Iteration 15
# Completing Iteration 15 (approx. per word bound = -3.593, relative change = 2.113e-04)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 16
# Completed M-Step, Iteration 16
# Completing Iteration 16 (approx. per word bound = -3.593, relative change = 1.926e-04)
#
# Completed E-Step, Iteration 17
# Completed M-Step, Iteration 17
# Completing Iteration 17 (approx. per word bound = -3.592, relative change = 1.769e-04)
#
# Completed E-Step, Iteration 18
# Completed M-Step, Iteration 18
# Completing Iteration 18 (approx. per word bound = -3.591, relative change = 1.637e-04)
#
# Completed E-Step, Iteration 19
# Completed M-Step, Iteration 19
# Completing Iteration 19 (approx. per word bound = -3.591, relative change = 1.524e-04)
#
# Completed E-Step, Iteration 20
# Completed M-Step, Iteration 20
# Completing Iteration 20 (approx. per word bound = -3.590, relative change = 1.425e-04)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 21
# Completed M-Step, Iteration 21
# Completing Iteration 21 (approx. per word bound = -3.590, relative change = 1.340e-04)
#
# Completed E-Step, Iteration 22
# Completed M-Step, Iteration 22
# Completing Iteration 22 (approx. per word bound = -3.589, relative change = 1.263e-04)
#
# Completed E-Step, Iteration 23
# Completed M-Step, Iteration 23
# Completing Iteration 23 (approx. per word bound = -3.589, relative change = 1.195e-04)
#
# Completed E-Step, Iteration 24
# Completed M-Step, Iteration 24
# Completing Iteration 24 (approx. per word bound = -3.589, relative change = 1.133e-04)
#
# Completed E-Step, Iteration 25
# Completed M-Step, Iteration 25
# Completing Iteration 25 (approx. per word bound = -3.588, relative change = 1.076e-04)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 26
# Completed M-Step, Iteration 26
# Completing Iteration 26 (approx. per word bound = -3.588, relative change = 1.024e-04)
#
# Completed E-Step, Iteration 27
# Completed M-Step, Iteration 27
# Completing Iteration 27 (approx. per word bound = -3.587, relative change = 9.765e-05)
#
# Completed E-Step, Iteration 28
# Completed M-Step, Iteration 28
# Completing Iteration 28 (approx. per word bound = -3.587, relative change = 9.320e-05)
#
# Completed E-Step, Iteration 29
# Completed M-Step, Iteration 29
# Completing Iteration 29 (approx. per word bound = -3.587, relative change = 8.905e-05)
#
# Completed E-Step, Iteration 30
# Completed M-Step, Iteration 30
# Completing Iteration 30 (approx. per word bound = -3.586, relative change = 8.518e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 31
# Completed M-Step, Iteration 31
# Completing Iteration 31 (approx. per word bound = -3.586, relative change = 8.152e-05)
#
# Completed E-Step, Iteration 32
# Completed M-Step, Iteration 32
# Completing Iteration 32 (approx. per word bound = -3.586, relative change = 7.809e-05)
#
# Completed E-Step, Iteration 33
# Completed M-Step, Iteration 33
# Completing Iteration 33 (approx. per word bound = -3.586, relative change = 7.493e-05)
#
# Completed E-Step, Iteration 34
# Completed M-Step, Iteration 34
# Completing Iteration 34 (approx. per word bound = -3.585, relative change = 7.186e-05)
#
# Completed E-Step, Iteration 35
# Completed M-Step, Iteration 35
# Completing Iteration 35 (approx. per word bound = -3.585, relative change = 6.901e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 36
# Completed M-Step, Iteration 36
# Completing Iteration 36 (approx. per word bound = -3.585, relative change = 6.630e-05)
#
# Completed E-Step, Iteration 37
# Completed M-Step, Iteration 37
# Completing Iteration 37 (approx. per word bound = -3.585, relative change = 6.374e-05)
#
# Completed E-Step, Iteration 38
# Completed M-Step, Iteration 38
# Completing Iteration 38 (approx. per word bound = -3.584, relative change = 6.129e-05)
#
# Completed E-Step, Iteration 39
# Completed M-Step, Iteration 39
# Completing Iteration 39 (approx. per word bound = -3.584, relative change = 5.902e-05)
#
# Completed E-Step, Iteration 40
# Completed M-Step, Iteration 40
# Completing Iteration 40 (approx. per word bound = -3.584, relative change = 5.683e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 41
# Completed M-Step, Iteration 41
# Completing Iteration 41 (approx. per word bound = -3.584, relative change = 5.476e-05)
#
# Completed E-Step, Iteration 42
# Completed M-Step, Iteration 42
# Completing Iteration 42 (approx. per word bound = -3.584, relative change = 5.280e-05)
#
# Completed E-Step, Iteration 43
# Completed M-Step, Iteration 43
# Completing Iteration 43 (approx. per word bound = -3.583, relative change = 5.096e-05)
#
# Completed E-Step, Iteration 44
# Completed M-Step, Iteration 44
# Completing Iteration 44 (approx. per word bound = -3.583, relative change = 4.918e-05)
#
# Completed E-Step, Iteration 45
# Completed M-Step, Iteration 45
# Completing Iteration 45 (approx. per word bound = -3.583, relative change = 4.752e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 46
# Completed M-Step, Iteration 46
# Completing Iteration 46 (approx. per word bound = -3.583, relative change = 4.596e-05)
#
# Completed E-Step, Iteration 47
# Completed M-Step, Iteration 47
# Completing Iteration 47 (approx. per word bound = -3.583, relative change = 4.447e-05)
#
# Completed E-Step, Iteration 48
# Completed M-Step, Iteration 48
# Completing Iteration 48 (approx. per word bound = -3.583, relative change = 4.304e-05)
#
# Completed E-Step, Iteration 49
# Completed M-Step, Iteration 49
# Completing Iteration 49 (approx. per word bound = -3.582, relative change = 4.171e-05)
#
# Completed E-Step, Iteration 50
# Completed M-Step, Iteration 50
# Completing Iteration 50 (approx. per word bound = -3.582, relative change = 4.046e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 51
# Completed M-Step, Iteration 51
# Completing Iteration 51 (approx. per word bound = -3.582, relative change = 3.926e-05)
#
# Completed E-Step, Iteration 52
# Completed M-Step, Iteration 52
# Completing Iteration 52 (approx. per word bound = -3.582, relative change = 3.813e-05)
#
# Completed E-Step, Iteration 53
# Completed M-Step, Iteration 53
# Completing Iteration 53 (approx. per word bound = -3.582, relative change = 3.704e-05)
#
# Completed E-Step, Iteration 54
# Completed M-Step, Iteration 54
# Completing Iteration 54 (approx. per word bound = -3.582, relative change = 3.603e-05)
#
# Completed E-Step, Iteration 55
# Completed M-Step, Iteration 55
# Completing Iteration 55 (approx. per word bound = -3.582, relative change = 3.505e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 56
# Completed M-Step, Iteration 56
# Completing Iteration 56 (approx. per word bound = -3.582, relative change = 3.413e-05)
#
# Completed E-Step, Iteration 57
# Completed M-Step, Iteration 57
# Completing Iteration 57 (approx. per word bound = -3.581, relative change = 3.327e-05)
#
# Completed E-Step, Iteration 58
# Completed M-Step, Iteration 58
# Completing Iteration 58 (approx. per word bound = -3.581, relative change = 3.240e-05)
#
# Completed E-Step, Iteration 59
# Completed M-Step, Iteration 59
# Completing Iteration 59 (approx. per word bound = -3.581, relative change = 3.166e-05)
#
# Completed E-Step, Iteration 60
# Completed M-Step, Iteration 60
# Completing Iteration 60 (approx. per word bound = -3.581, relative change = 3.084e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 61
# Completed M-Step, Iteration 61
# Completing Iteration 61 (approx. per word bound = -3.581, relative change = 3.014e-05)
#
# Completed E-Step, Iteration 62
# Completed M-Step, Iteration 62
# Completing Iteration 62 (approx. per word bound = -3.581, relative change = 2.944e-05)
#
# Completed E-Step, Iteration 63
# Completed M-Step, Iteration 63
# Completing Iteration 63 (approx. per word bound = -3.581, relative change = 2.879e-05)
#
# Completed E-Step, Iteration 64
# Completed M-Step, Iteration 64
# Completing Iteration 64 (approx. per word bound = -3.581, relative change = 2.815e-05)
#
# Completed E-Step, Iteration 65
# Completed M-Step, Iteration 65
# Completing Iteration 65 (approx. per word bound = -3.581, relative change = 2.754e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 66
# Completed M-Step, Iteration 66
# Completing Iteration 66 (approx. per word bound = -3.580, relative change = 2.695e-05)
#
# Completed E-Step, Iteration 67
# Completed M-Step, Iteration 67
# Completing Iteration 67 (approx. per word bound = -3.580, relative change = 2.639e-05)
#
# Completed E-Step, Iteration 68
# Completed M-Step, Iteration 68
# Completing Iteration 68 (approx. per word bound = -3.580, relative change = 2.582e-05)
#
# Completed E-Step, Iteration 69
# Completed M-Step, Iteration 69
# Completing Iteration 69 (approx. per word bound = -3.580, relative change = 2.533e-05)
#
# Completed E-Step, Iteration 70
# Completed M-Step, Iteration 70
# Completing Iteration 70 (approx. per word bound = -3.580, relative change = 2.483e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 71
# Completed M-Step, Iteration 71
# Completing Iteration 71 (approx. per word bound = -3.580, relative change = 2.432e-05)
#
# Completed E-Step, Iteration 72
# Completed M-Step, Iteration 72
# Completing Iteration 72 (approx. per word bound = -3.580, relative change = 2.384e-05)
#
# Completed E-Step, Iteration 73
# Completed M-Step, Iteration 73
# Completing Iteration 73 (approx. per word bound = -3.580, relative change = 2.339e-05)
#
# Completed E-Step, Iteration 74
# Completed M-Step, Iteration 74
# Completing Iteration 74 (approx. per word bound = -3.580, relative change = 2.296e-05)
#
# Completed E-Step, Iteration 75
# Completed M-Step, Iteration 75
# Completing Iteration 75 (approx. per word bound = -3.580, relative change = 2.250e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 76
# Completed M-Step, Iteration 76
# Completing Iteration 76 (approx. per word bound = -3.580, relative change = 2.213e-05)
#
# Completed E-Step, Iteration 77
# Completed M-Step, Iteration 77
# Completing Iteration 77 (approx. per word bound = -3.580, relative change = 2.182e-05)
#
# Completed E-Step, Iteration 78
# Completed M-Step, Iteration 78
# Completing Iteration 78 (approx. per word bound = -3.579, relative change = 2.135e-05)
#
# Completed E-Step, Iteration 79
# Completed M-Step, Iteration 79
# Completing Iteration 79 (approx. per word bound = -3.579, relative change = 2.103e-05)
#
# Completed E-Step, Iteration 80
# Completed M-Step, Iteration 80
# Completing Iteration 80 (approx. per word bound = -3.579, relative change = 2.068e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 81
# Completed M-Step, Iteration 81
# Completing Iteration 81 (approx. per word bound = -3.579, relative change = 2.036e-05)
#
# Completed E-Step, Iteration 82
# Completed M-Step, Iteration 82
# Completing Iteration 82 (approx. per word bound = -3.579, relative change = 2.002e-05)
#
# Completed E-Step, Iteration 83
# Completed M-Step, Iteration 83
# Completing Iteration 83 (approx. per word bound = -3.579, relative change = 1.975e-05)
#
# Completed E-Step, Iteration 84
# Completed M-Step, Iteration 84
# Completing Iteration 84 (approx. per word bound = -3.579, relative change = 1.941e-05)
#
# Completed E-Step, Iteration 85
# Completed M-Step, Iteration 85
# Completing Iteration 85 (approx. per word bound = -3.579, relative change = 1.919e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 86
# Completed M-Step, Iteration 86
# Completing Iteration 86 (approx. per word bound = -3.579, relative change = 1.887e-05)
#
# Completed E-Step, Iteration 87
# Completed M-Step, Iteration 87
# Completing Iteration 87 (approx. per word bound = -3.579, relative change = 1.861e-05)
#
# Completed E-Step, Iteration 88
# Completed M-Step, Iteration 88
# Completing Iteration 88 (approx. per word bound = -3.579, relative change = 1.841e-05)
#
# Completed E-Step, Iteration 89
# Completed M-Step, Iteration 89
# Completing Iteration 89 (approx. per word bound = -3.579, relative change = 1.813e-05)
#
# Completed E-Step, Iteration 90
# Completed M-Step, Iteration 90
# Completing Iteration 90 (approx. per word bound = -3.579, relative change = 1.791e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 91
# Completed M-Step, Iteration 91
# Completing Iteration 91 (approx. per word bound = -3.579, relative change = 1.765e-05)
#
# Completed E-Step, Iteration 92
# Completed M-Step, Iteration 92
# Completing Iteration 92 (approx. per word bound = -3.578, relative change = 1.751e-05)
#
# Completed E-Step, Iteration 93
# Completed M-Step, Iteration 93
# Completing Iteration 93 (approx. per word bound = -3.578, relative change = 1.727e-05)
#
# Completed E-Step, Iteration 94
# Completed M-Step, Iteration 94
# Completing Iteration 94 (approx. per word bound = -3.578, relative change = 1.710e-05)
#
# Completed E-Step, Iteration 95
# Completed M-Step, Iteration 95
# Completing Iteration 95 (approx. per word bound = -3.578, relative change = 1.691e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 96
# Completed M-Step, Iteration 96
# Completing Iteration 96 (approx. per word bound = -3.578, relative change = 1.672e-05)
#
# Completed E-Step, Iteration 97
# Completed M-Step, Iteration 97
# Completing Iteration 97 (approx. per word bound = -3.578, relative change = 1.655e-05)
#
# Completed E-Step, Iteration 98
# Completed M-Step, Iteration 98
# Completing Iteration 98 (approx. per word bound = -3.578, relative change = 1.644e-05)
#
# Completed E-Step, Iteration 99
# Completed M-Step, Iteration 99
# Completing Iteration 99 (approx. per word bound = -3.578, relative change = 1.622e-05)
#
# Completed E-Step, Iteration 100
# Completed M-Step, Iteration 100
# Completing Iteration 100 (approx. per word bound = -3.578, relative change = 1.611e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 101
# Completed M-Step, Iteration 101
# Completing Iteration 101 (approx. per word bound = -3.578, relative change = 1.597e-05)
#
# Completed E-Step, Iteration 102
# Completed M-Step, Iteration 102
# Completing Iteration 102 (approx. per word bound = -3.578, relative change = 1.577e-05)
#
# Completed E-Step, Iteration 103
# Completed M-Step, Iteration 103
# Completing Iteration 103 (approx. per word bound = -3.578, relative change = 1.565e-05)
#
# Completed E-Step, Iteration 104
# Completed M-Step, Iteration 104
# Completing Iteration 104 (approx. per word bound = -3.578, relative change = 1.544e-05)
#
# Completed E-Step, Iteration 105
# Completed M-Step, Iteration 105
# Completing Iteration 105 (approx. per word bound = -3.578, relative change = 1.536e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 106
# Completed M-Step, Iteration 106
# Completing Iteration 106 (approx. per word bound = -3.578, relative change = 1.518e-05)
#
# Completed E-Step, Iteration 107
# Completed M-Step, Iteration 107
# Completing Iteration 107 (approx. per word bound = -3.578, relative change = 1.501e-05)
#
# Completed E-Step, Iteration 108
# Completed M-Step, Iteration 108
# Completing Iteration 108 (approx. per word bound = -3.578, relative change = 1.489e-05)
#
# Completed E-Step, Iteration 109
# Completed M-Step, Iteration 109
# Completing Iteration 109 (approx. per word bound = -3.578, relative change = 1.475e-05)
#
# Completed E-Step, Iteration 110
# Completed M-Step, Iteration 110
# Completing Iteration 110 (approx. per word bound = -3.577, relative change = 1.460e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 111
# Completed M-Step, Iteration 111
# Completing Iteration 111 (approx. per word bound = -3.577, relative change = 1.445e-05)
#
# Completed E-Step, Iteration 112
# Completed M-Step, Iteration 112
# Completing Iteration 112 (approx. per word bound = -3.577, relative change = 1.432e-05)
#
# Completed E-Step, Iteration 113
# Completed M-Step, Iteration 113
# Completing Iteration 113 (approx. per word bound = -3.577, relative change = 1.415e-05)
#
# Completed E-Step, Iteration 114
# Completed M-Step, Iteration 114
# Completing Iteration 114 (approx. per word bound = -3.577, relative change = 1.403e-05)
#
# Completed E-Step, Iteration 115
# Completed M-Step, Iteration 115
# Completing Iteration 115 (approx. per word bound = -3.577, relative change = 1.390e-05)
#
# Topic 1: network, structur, result, optim, use
#  Topic 2: heisenberg, quantum, carlo, mont, use
#  Topic 3: phase, surfac, structur, model, fluid
#  Topic 4: system, well, temperatur, expect, finit
#  Topic 5: disord, surfac, equat, simul, adsorpt
#  Topic 6: contribut, factor, partial, correl, larger
#  Topic 7: state, basi, can, show, obtain
#  Topic 8: chain, studi, polym, kinet, dynam
#  Topic 9: field, temperatur, critic, system, calcul
#  Topic 10: behavior, dynam, result, grain, critic
#  Topic 11: result, discuss, symmetri, function, scale
#  Topic 12: energi, exact, ground, condit, state
#  Topic 13: present, function, advanc, recent, analyt
#  Topic 14: combin, shown, model, mont, carlo
#  Topic 15: high, exist, quantum, mont, carlo
#  Topic 16: featur, addit, theori, kinet, transport
#  Topic 17: squar, lattic, model, use, order
#  Topic 18: set, quantum, use, order, model
#  Topic 19: data, use, mont, carlo, model
#  Topic 20: critic, expon, experiment, temperatur, scale
#
# Completed E-Step, Iteration 116
# Completed M-Step, Iteration 116
# Model Converged

# %%
init_type="Spectral"; seed=None; max_em_its=500; emtol=1e-5; verbose=True; reportevery=5; 
LDAbeta=True; interactions=True; ngroups=1; model=None; gamma_prior="Pooled"; 
sigma_prior=0; kappa_prior="L1"

# %%
robjects.globalenv['stm'](robjects.r("processed_corpus$documents"),
                          robjects.r("processed_corpus$vocab"), K=20,
                          prevalence=robjects.Formula("~s(date)"),
                          data=robjects.r("processed_corpus$meta"))
# Out:
# <ListVector - Python:0x10c6e0cb0 / R:0x10ce81f10>
# [ListVector, Array, ListVector, RNULLType]
# <ListVector - Python:0x10c6e0cb0 / R:0x10ce81f10>
# [ListVector, Array, ListVector, RNULLType]
#   vocab: <class 'rpy2.robjects.vectors.Array'>
#   <Array - Python:0x10c6e0c20 / R:0x1107f7a00>
# [str, str, str, ..., str, str, str]
# <ListVector - Python:0x10c6e0cb0 / R:0x10ce81f10>
# [ListVector, Array, ListVector, RNULLType]
#   model: <type 'rpy2.rinterface.RNULLType'>
#   rpy2.rinterface.NULL
